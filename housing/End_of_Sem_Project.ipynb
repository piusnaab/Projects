# %%
# Libraries
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#read data into notebook
GH_Housing = pd.read_csv("Gh_house_rentals.csv")
GH_Housing.head()
# Out:
#                                                  url listing_type  \
# 0  https://tonaton.com/a-MfYFNdCgCTytOcmvZIh0Kzrj...      rentals
# 1  https://tonaton.com/a-MfYFNdCgwtb8Itol9odpMPvC...      rentals
# 2  https://tonaton.com/a-MfYFNdCgPjnzPYwNFEv5JrGy...      rentals
# 3  https://tonaton.com/a-MfYFNdCgwmXHQRNJiSR3rok8...      rentals
# 4  https://tonaton.com/a-MfYFNdCgn3Bcs511lKnFE19i...      rentals
#
#                                                 name    price  category  \
# 0  2bdrm Apartment in Charclem Ventures, East Leg...   9196.0     Flats
# 1             2bdrm Apartment in , Dzorwulu for rent   7500.0     Flats
# 2           4bdrm House in Lakeside Estate, for Rent  11200.0  Detached
# 3    3bdrm House in Ayathar Bedroom, Teshie for Rent   2500.0  Detached
# 4  3bdrm House in Manet Viile Estate, Spintex for...   9146.0  Detached
#
#    bedrooms  bathrooms  floor_area  \
# 0         2          2       145.0
# 1         2          2       100.0
# ...

# %%
GH_Housing.describe()
# Out:
#               price      bedrooms     bathrooms    floor_area           lat  \
# count  18199.000000  18263.000000  18263.000000  18221.000000  18263.000000
# mean    7986.791857      2.459618      2.565405    556.611053      5.725899
# std    10391.854437      1.263888      1.378759   1045.060765      0.453726
# min      416.000000      1.000000      1.000000     10.000000      4.849041
# 25%     1700.000000      2.000000      1.000000    100.000000      5.592619
# 50%     3500.000000      2.000000      2.000000    145.000000      5.637614
# 75%     9800.000000      3.000000      3.000000    600.000000      5.682581
# max    59524.000000     20.000000     20.000000   5000.000000      9.410999
#
#                 lng
# count  18263.000000
# mean      -0.246991
# std        0.322948
# min       -2.579248
# 25%       -0.215087
# 50%       -0.161359
# 75%       -0.135459
# max        0.563609

# %%
GH_Housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18263 entries, 0 to 18262
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   url            18263 non-null  object
#  1   listing_type   18263 non-null  object
#  2   name           18222 non-null  object
#  3   price          18199 non-null  float64
#  4   category       18263 non-null  object
#  5   bedrooms       18263 non-null  int64
#  6   bathrooms      18263 non-null  int64
#  7   floor_area     18221 non-null  float64
#  8   location       18263 non-null  object
#  9   condition      18263 non-null  object
#  10  amenities      18195 non-null  object
#  11  region         18263 non-null  object
#  12  locality       18263 non-null  object
#  13  parking_space  18263 non-null  bool
#  14  is_furnished   18263 non-null  object
#  15  lat            18263 non-null  float64
#  16  lng            18263 non-null  float64
# ...
